die Kluft zwischen Jung und Alt: Jüngere Beschäftigte müssen nicht nur 
höhere Beiträge zur Rentenversicherung leisten, um die Rentengarantie zu 
finanzieren, sondern über ihre Steuern auch noch die Aktivrente.

Viertens bleiben selbstständig tätige Rentnerinnen und Rentner außen vor. 
Es gibt keinen sachlichen Grund, warum sie gegenüber Angestellten 
benachteiligt werden sollten. Eine Einbeziehung wäre jedoch teuer und 
administrativ aufwendig.

Gleichzeitig gibt es bessere Alternativen: Die Bundesregierung sollte 
Arbeitsverträge im Alter flexibler gestalten, damit ältere Beschäftigte 
beim bisherigen Arbeitgeber und in vertrauten Tätigkeiten weiterarbeiten 
können. Hierzu müsste etwa das Kündigungsrecht im Alter reformiert 
werden, um Weiterbeschäftigung zu erleichtern.

Privilegien abbauen
Auch sollten Sonderregelungen, wie die abschlagsfreie Rente nach 45 
Beitragsjahren, kritisch überprüft und teilweise abgeschafft werden. Nur 
knapp die Hälfte der Beschäftigten arbeitet bis zum gesetzlichen 
Renteneintrittsalter. Viele könnten es gesundheitlich, tun es aber aus 
finanziellen Gründen nicht. Durch den Abbau von Privilegien und gezielte 
Anreize könnte ein längeres Arbeiten erleichtert werden.

Genauso wichtig sind Investitionen in Pflege- und Gesundheitsinfrastruktur. 
Viele Menschen möchten im Alter gerne weiterarbeiten, können es aber 
nicht, weil sie Angehörige betreuen oder gesundheitlich eingeschränkt 
sind. Diese strukturellen Hürden müssen abgebaut werden, auch wenn das 
Zeit braucht.

Aus wirtschaftlichen Gründen und aus Gründen der Gerechtigkeit zwischen 
Jung und Alt sowie zwischen Arm und Reich muss die Politik Wege finden, 
die Beschäftigung im Alter zu erhöhen und gleichzeitig Altersarmut zu 
bekämpfen. Die Aktivrente kann – im besten Fall – ein Baustein sein. Sie 
schafft jedoch auch neue Ungleichgewichte, die die Politik entschlossen 
adressieren muss. Das Ziel, insbesondere Altersarmut zu reduzieren, darf 
dabei nicht aus dem Blick geraten."""

# %%
# Version 1: Far more repetitive (rephrasing first two sentences)
repetitive_rephrase_text = """Der Fachkräftemangel bedroht zunehmend die 
Existenz vieler Unternehmen und belastet die deutsche Wirtschaft. Ein 
enormes Potenzial, um dem entgegenzuwirken, liegt in der Erwerbstätigkeit 
nach dem Renteneintritt.

Die Knappheit qualifizierter Arbeitskräfte gefährdet immer stärker das 
Überleben zahlreicher Betriebe und beeinträchtigt die Volkswirtschaft 
Deutschlands. Eine riesige Chance zur Gegensteuerung findet sich in der 
beruflichen Tätigkeit nach Erreichen des Rentelalters.

Der Mangel an Fachpersonal stellt eine wachsende Bedrohung für viele 
Firmen dar und schwächt die deutsche Ökonomie. Ein gewaltiges Potenzial 
zur Bekämpfung liegt in der Fortsetzung der Berufstätigkeit nach dem 
Eintritt in die Rente.

Das Fehlen von Spezialisten bedroht mehr und mehr die Existenzfähigkeit 
verschiedener Unternehmen und schadet der deutschen Wirtschaftsleistung. 
findet sich in der Erwerbsweiterführung nach dem Ruhestandsbeginn.

Der Qualifikationsmangel stellt eine zunehmende Herausforderung für 
unzählige Firmen dar und schwächt die deutsche Wirtschaftskapazität. Ein 
enormes Lösungspotenzial liegt in der Arbeitsfortführung nach dem 
Pensionseintritt.

Die Kompetenzverknappung gefährdet massiv die Überlebensmöglichkeiten 
vieler Gesellschaften und belastet die deutsche Wirtschaftsordnung. Eine 
beträchtliche Chance zur Problembekämpfung besteht in der beruflichen 
Aktivität nach dem Rentenantritt.

Das Können-Defizit bedroht intensiv die Existenzmöglichkeiten 
verschiedenster Betriebe und schadet der deutschen Ökonomie. Ein 
gewichtiges Potenzial zur Lösung findet sich in der Erwerbsausübung nach 
dem Alterseintritt.

Die Fertigkeitsknappheit stellt eine ernsthafte Gefährdung für zahlreiche 
Organisationen dar und beeinträchtigt die deutsche Volkswirtschaft. Eine 
bedeutende Möglichkeit zur Abhilfe liegt in der Arbeitsausführung nach 
dem Ruhestandsantritt.

Der Wissensmangel gefährdet nachhaltig die Lebensmöglichkeiten diverser 
Unternehmen und schwächt die deutsche Wirtschaftsstruktur. Ein 
außergewöhnliches Potenzial zur Entgegenwirkung besteht in der 
beruflichen Weiterarbeit nach dem Pensionsstart.

Die Talentverknappung bedroht kontinuierlich die Existenzfähigkeit 
unterschiedlicher Firmen und belastet die deutsche Wirtschaftsleistung. 
Eine erhebliche Chance zur Gegensteuerung findet sich in der 
Erwerbsfortsetzung nach dem Rentenübertritt.

Das Expertisedefizit stellt eine wachsende Bedrohung für vielerlei 
Betriebe dar und schadet der deutschen Volkswirtschaft. Ein wichtiges 
Lösungspotenzial liegt in der Arbeitsweiterführung nach dem 
Altersruhestand."""

# %%
# Version 2: Completely repetitive (exact copy of first two sentences)
completely_repetitive_text = """Der Fachkräftemangel bedroht zunehmend 
die Existenz vieler Unternehmen und belastet die deutsche Wirtschaft. Ein 
enormes Potenzial, um dem entgegenzuwirken, liegt in der Erwerbstätigkeit 
nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt.

Der Fachkräftemangel bedroht zunehmend die Existenz vieler Unternehmen 
und belastet die deutsche Wirtschaft. Ein enormes Potenzial, um dem 
entgegenzuwirken, liegt in der Erwerbstätigkeit nach dem Renteneintritt."""

# %%
# Count words in all three texts
def count_words(text):
    return len(text.split())

print(f"Human text words: {count_words(human_text)}")
print(f"Repetitive rephrase text words: {count_words(repetitive_rephrase_text)}")
print(f"Completely repetitive text words: {count_words(completely_repetitive_text)}")

# Calculate how many more repetitions we need
human_words = count_words(human_text)
rephrase_words = count_words(repetitive_rephrase_text)
repetitive_words = count_words(completely_repetitive_text)

print(f"\nTarget length: {human_words} words")
print(f"Rephrase needs: {human_words - rephrase_words} more words")
print(f"Repetitive needs: {human_words - repetitive_words} more words")
# Out:
# Human text words: 633
# Repetitive rephrase text words: 637
# Completely repetitive text words: 650
#
# Target length: 633 words
# Rephrase needs: -4 more words
# Repetitive needs: -17 more words
